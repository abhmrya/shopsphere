# %%
lst = [1,2,3,4,5,6,7,8]

print(lst[-6:-4:1])
print(lst[2:-5])
# Out:
# Running cells with '.venv (3.13.2.final.0) (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Abhay/shopsphere/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
